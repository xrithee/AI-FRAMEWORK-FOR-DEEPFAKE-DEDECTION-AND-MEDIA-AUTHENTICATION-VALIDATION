# %% [markdown]
# # DataPreprocessing

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd

# %%
data = pd.read_json('intents.json')

# %%
data.head()
# Out:
#                                              intents
# 0  {'tag': 'greetings', 'patterns': ['Hello', 'Hi...
# 1  {'tag': 'deepfake_identification', 'patterns':...
# 2  {'tag': 'deepfake_detection_signs', 'patterns'...
# 3  {'tag': 'deepfake_detection_tools', 'patterns'...
# 4  {'tag': 'deepfake_impact', 'patterns': ['How d...

# %%
data.shape
# Out:
# (51, 1)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 51 entries, 0 to 50
# Data columns (total 1 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   intents  51 non-null     object
# dtypes: object(1)
# memory usage: 816.0+ bytes

# %%
df = data.dropna()

# %%
df.isnull().sum()
# Out:
# intents    0
# dtype: int64

# %%
df.info
# Out:
# <bound method DataFrame.info of                                               intents
# 0   {'tag': 'greetings', 'patterns': ['Hello', 'Hi...
# 1   {'tag': 'deepfake_identification', 'patterns':...
# 2   {'tag': 'deepfake_detection_signs', 'patterns'...
# 3   {'tag': 'deepfake_detection_tools', 'patterns'...
# 4   {'tag': 'deepfake_impact', 'patterns': ['How d...
# 5   {'tag': 'deepfake_legal_aspects', 'patterns': ...
# 6   {'tag': 'deepfake_detection_reliability', 'pat...
# 7   {'tag': 'deepfake_use_cases', 'patterns': ['Wh...
# 8   {'tag': 'deepfake_future', 'patterns': ['What ...
# 9   {'tag': 'deepfake_education', 'patterns': ['Ho...
# 10  {'tag': 'deepfake_media_literacy', 'patterns':...
# 11  {'tag': 'deepfake_research', 'patterns': ['Wha...
# 12  {'tag': 'deepfake_digital_forensics', 'pattern...
# 13  {'tag': 'deepfake_benefits', 'patterns': ['Wha...
# 14  {'tag': 'deepfake_ethical_concerns', 'patterns...
# 15  {'tag': 'deepfake_media_regulation', 'patterns...
# ...

# %%
df.columns
# Out:
# Index(['intents'], dtype='object')

# %%
df.size
# Out:
# 51

# %%
df.describe()
# Out:
#                                                   intents
# count                                                  51
# unique                                                 51
# top     {'tag': 'greetings', 'patterns': ['Hello', 'Hi...
# freq                                                    1

# %%
df.head()
# Out:
#                                              intents
# 0  {'tag': 'greetings', 'patterns': ['Hello', 'Hi...
# 1  {'tag': 'deepfake_identification', 'patterns':...
# 2  {'tag': 'deepfake_detection_signs', 'patterns'...
# 3  {'tag': 'deepfake_detection_tools', 'patterns'...
# 4  {'tag': 'deepfake_impact', 'patterns': ['How d...

# %%
df.head()
# Out:
#                                              intents
# 0  {'tag': 'greetings', 'patterns': ['Hello', 'Hi...
# 1  {'tag': 'deepfake_identification', 'patterns':...
# 2  {'tag': 'deepfake_detection_signs', 'patterns'...
# 3  {'tag': 'deepfake_detection_tools', 'patterns'...
# 4  {'tag': 'deepfake_impact', 'patterns': ['How d...
